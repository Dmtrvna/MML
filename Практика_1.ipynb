# %% [markdown]
# <a href="https://colab.research.google.com/github/Dmtrvna/MML/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ММО Практика 1

# %% [markdown]
# # Наборы данных по вариантам

# %% [markdown]
# Вариант №4
# https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset
#
# Набор данных о депрессии среди студентов

# %%
# установка зависимостей
# !pip install pandas matplotlib seaborn

# %%
# Импорт библиотек и данных
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/student_depression_dataset.csv")

# %%
#2 Вывод первых 5 строк датафрейма
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
# Краткая информация о наборе данных
df.info() # выводит типы данных и не-null значения в столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
# Статистический разбор
df.describe() # Выводит статистику для числовых переменных
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
df.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                          object
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# id: 27901 уникальных значений
# Gender: 2 уникальных значений
# Age: 34 уникальных значений
# City: 52 уникальных значений
# Profession: 14 уникальных значений
# Academic Pressure: 6 уникальных значений
# Work Pressure: 3 уникальных значений
# CGPA: 332 уникальных значений
# Study Satisfaction: 6 уникальных значений
# Job Satisfaction: 5 уникальных значений
# Sleep Duration: 5 уникальных значений
# Dietary Habits: 4 уникальных значений
# Degree: 28 уникальных значений
# Have you ever had suicidal thoughts ?: 2 уникальных значений
# Work/Study Hours: 13 уникальных значений
# Financial Stress: 6 уникальных значений
# Family History of Mental Illness: 2 уникальных значений
# Depression: 2 уникальных значений

# %% [markdown]
# **⏰ задача**
#
# Определить типы переменных
# - номинальные переменные (не имеют порядка и сравнения)
# - порядковые переменные (имеют порядок, но не имеют смысла мат операции)
# - числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
#
# Вывести статистику для числовых и для категориальных переменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему

# %% [markdown]
# #### Типы переменных

# %% [markdown]
# Номинальные переменные (не имеют порядка и сравнения):
#
# *   Gender — пол (2 значения), без порядка;
# *   City — город проживания, категории без порядка;
# *   Profession — профессия студента, категории без порядка;
# *   Dietary Habits — пищевые привычки (4 значения), скорее номинальная, но если значения — шкала от маленького к большему по уровню здоровья, то будет порядковой;
# *   Have you ever had suicidal thoughts ? — были ли суицидальные мысли (2 значения), без порядка;
# *   Family History of Mental Illness — семейная история психических заболеваний (2 значения);
# *   Depression — наличие депрессии, 2 уникальных значения (0/1 or Yes/No) — целевая бинарная номинальная.
#
# Порядковые переменные (с порядком, без смысла мат операций):
#
# *   Academic Pressure — уровень учебного давления (6 значений), вероятно шкала от маленького к большему, упорядоченная;
# *   Work Pressure — уровень рабочего давления (3 значения), тоже скорее шкала;
# *   Study Satisfaction — удовлетворённость учёбой (6 значений), вероятно шкала;
# *   Job Satisfaction — удовлетворённость работой (5 значений), вероятно шкала;
# *   Sleep Duration — длительность сна (5 значений), скорее всего классификация, допустим "мало"/"нормально"/"много";
# *   Degree — уровень обучения (28 значений), скорее номинальная, хотя может быть некоторый порядок (бакалавр, магистр, кандидат и т.п.), но без числовой операции — порядковая;
# *   Financial Stress — уровень финансового стресса (6 значений), вероятно порядковая шкала.
#
# Числовые непрерывные переменные (с порядком и смыслом мат операций):
#
# *   Age — возраст, количественная непрерывная переменная;
# *   CGPA — средний балл, числовая оценка — количественная непрерывная;
# *   Work/Study Hours — часы работы и учёбы, количественная непрерывная.

# %%
# Распределение по типам переменных
categorical = ["Gender", "City", "Profession", "Have you ever had suicidal thoughts ?", "Family History of Mental Illness", "Depression", "Dietary Habits", "Degree"]
ordinal = ["Academic Pressure", "Work Pressure", "Study Satisfaction", "Job Satisfaction", "Sleep Duration", "Financial Stress"]
numeric = ["Age", "CGPA", "Work/Study Hours"]

# Статистика для числовых и категориальных переменных
df[numeric].describe()
# Out:
#                 Age          CGPA  Work/Study Hours
# count  27901.000000  27901.000000      27901.000000
# mean      25.822300      7.656104          7.156984
# std        4.905687      1.470707          3.707642
# min       18.000000      0.000000          0.000000
# 25%       21.000000      6.290000          4.000000
# 50%       25.000000      7.770000          8.000000
# 75%       30.000000      8.920000         10.000000
# max       59.000000     10.000000         12.000000

# %%
df[categorical].describe(include="all")
# Out:
#        Gender    City Profession Have you ever had suicidal thoughts ?  \
# count   27901   27901      27901                                 27901
# unique      2      52         14                                     2
# top      Male  Kalyan    Student                                   Yes
# freq    15547    1570      27870                                 17656
# mean      NaN     NaN        NaN                                   NaN
# std       NaN     NaN        NaN                                   NaN
# min       NaN     NaN        NaN                                   NaN
# 25%       NaN     NaN        NaN                                   NaN
# 50%       NaN     NaN        NaN                                   NaN
# 75%       NaN     NaN        NaN                                   NaN
# max       NaN     NaN        NaN                                   NaN
#
#        Family History of Mental Illness    Depression Dietary Habits  \
# ...

# %% [markdown]
# ## Визуализация распределения переменных
#
# ### Описание:
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### Шаги:

# %% [markdown]
# #### 1. **Гистограмма для числовых переменных**

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Является ли распределение нормальным или отлично от него?
# - Концентрация большинства значений
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
#
# p.s. 3-5 самых показательных примеров.

# %%
# Числовые переменные
numeric = ["Age", "CGPA", "Work/Study Hours"]

# Гистограмма для числовых переменных
fig, axes = plt.subplots(1, len(numeric), figsize=(6 * len(numeric), 4))

for ax, col in zip(axes, numeric):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# График распределения Age (Возраст) показывает, что большинство людей молодые, в основном от 18 до 35 лет. График выглядит “рвано”, с сильными перепадами, что не похоже на нормальное распределение. Таким образом, в дальнейшем мы будем исследовать наличие депресии у студентов в возрасте от 18 до 35 лет.
#
# График CGPA (Средний балл) показывает, что у большинства опрошеннных средний балл довольно высокий и составляет от 5 до 10, почти никто не получает очень низкие оценки. График не ровный, а с “лесенкой”, значит оценки часто повторяются и нормального распределения тут нет.
#
# В графике Work/Study Hours (Часы работы/учёбы) мы видим много пробелов, значит нрмального распределения тут нет. По графику можно сделать вывод, что больше всего людей работает/учится по 8-12 часов.

# %%
# Распределение Work/Study Hours по типу обучения (study_type)
# 1. Распределение Work/Study Hours по study_type
sns.histplot(data=df, x="Work/Study Hours", hue="Profession", kde=True, multiple="stack")
plt.title("Work/Study Hours по типу обучения")
plt.show()

# # 2. Распределение CGPA по major
# sns.histplot(data=df, x="CGPA", hue="major", kde=True, multiple="stack")
# plt.title("CGPA по специальности")
# plt.show()

# # 3. Распределение Age по gender
# sns.histplot(data=df, x="Age", hue="gender", kde=True, multiple="stack")
# plt.title("Age по полу")
# plt.show()

# %% [markdown]
# #### 2. **Столбчатая диаграмма для категориальной переменной `Class`**

# %%
sns.countplot(x='quality', data=df)
plt.title('Распределение quality')
plt.xlabel('quality')
plt.ylabel('Количество')
plt.show()

# ниже код для оптимизации вывода всех категориальных переменных
#num_cols = df.select_dtypes(include='category').columns # или object
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.histplot(df[col], kde=True, ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - в каких значениях концентрируентся переменная?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)

# %% [markdown]
# #### 3. **Боксплот для числовой переменной**

# %%
sns.boxplot(x=df['chlorides'])
plt.title('Boxplot chlorides')
plt.xlabel('chlorides')
plt.show()

#num_cols = df.select_dtypes(include='float').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.boxplot(df[col], ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Есть ли выбросы?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина). Определить различия по медиане

# %% [markdown]
# #### 4. **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты**

# %%
# Корреляционная матрица
correlation_matrix = df.corr()

# Визуализация тепловой карты
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица')
plt.show()

# %% [markdown]
# **если ValueError**

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('colName', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()

# %% [markdown]
# **задача ⏰**
#
# Интерпертировать полученный результат:
# - Какие переменные не коррелируют?
# - Какие переменные имеют сильную положительную корреляцию?
# - Какие переменные имеют сильную слабую корреляцию?
#
# p.s. сильная корреляция считаем abs(corr_coef) >= 0.7
